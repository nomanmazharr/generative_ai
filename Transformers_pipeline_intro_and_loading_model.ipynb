# %% [markdown]
# ### Loading pipeline from transformer

# %%
from transformers import pipeline

# %%
chatbot = pipeline(
    'conversational',
    model = 'facebook/blenderbot-400M-distill'
)

# %%
chatbot

# %% [markdown]
# #### adding prompt

# %%
user_message = """
  what are the jobs that pay most salary these days?
"""

# %%
from transformers import Conversation

# %%
text = Conversation(user_message)

# %%
text
# Out:
# Conversation id: 6f04143b-9c21-43b7-b70b-ffbb8f74fc25
# user:
#   what are the jobs that pay most salary these days?

# %% [markdown]
# #### output

# %%
chatbot(text)
# Out:
# No chat template is set for this tokenizer, falling back to a default class-level template. This is very error-prone, because models are often trained with templates different from the class default! Default chat templates are a legacy feature and will be removed in Transformers v4.43, at which point any code depending on them will stop working. We recommend setting a valid chat template before then to ensure that this model continues working without issues.
# Conversation id: 6f04143b-9c21-43b7-b70b-ffbb8f74fc25
# user:
#   what are the jobs that pay most salary these days?
#
# assistant:  I'm not sure, but I do know that the average salary in the US is $9.50 an hour.

# %%
chatbot(Conversation('Who was the top player in football in 2020'))
# Out:
# Conversation id: 8c7cef93-60cc-4e4c-b614-331ab6b5e5b4
# user: Who was the top player in football in 2020
# assistant:  I'm not sure, but I do know that the team with the most points at the end of the game wins.

# %%
chatbot(Conversation('Give me some cool suggestions like how can I enjoy summer'))
# Out:
# Conversation id: 7a2399a4-16e8-483f-9036-4cbba2fe7a07
# user: Give me some cool suggestions like how can I enjoy summer
# assistant:  I love the beach and the cool breezes and the sunshine.

# %%
chatbot(Conversation('Some of the more suggestions'))
# Out:
# Conversation id: 72c01912-ffca-4f2e-a493-d3a9aef0794b
# user: Some of the more suggestions
# assistant:  What do you have in mind? I'm always looking for something new to try.

# %%
text.add_message({
    "role" :'user',
    "content": 'give me some more suggestions'})

# %%
chatbot(text)
# Out:
# Conversation id: 6f04143b-9c21-43b7-b70b-ffbb8f74fc25
# user:
#   what are the jobs that pay most salary these days?
#
# assistant:  I'm not sure, but I do know that the average salary in the US is $9.50 an hour.
# user: give me some more suggestions
# user: give me some more suggestions
# assistant:  Well, if you are looking for a job that pays more than $9 an hour, you could try working in a call center.

# %%
text.add_message({
    'role': 'user',
    'content' : 'How about 2020 can you suggest some on that time'}
)

# %%
chatbot(text)
# Out:
# Conversation id: 6f04143b-9c21-43b7-b70b-ffbb8f74fc25
# user:
#   what are the jobs that pay most salary these days?
#
# assistant:  I'm not sure, but I do know that the average salary in the US is $9.50 an hour.
# user: give me some more suggestions
# user: give me some more suggestions
# assistant:  Well, if you are looking for a job that pays more than $9 an hour, you could try working in a call center.
# user: How about 2020 can you suggest some on that time
# user: How about 2020 can you suggest some on that time
# assistant:  Sure, I think that would be a good time to start looking for something in that timeframe.

# %%
text.add_message({'role': 'user',
                  'content': 'Then tell from that timeframe'

})

# %% [markdown]
# #### This model can take only 128 tokens as input increasing the number of tokens will result in index error.

# %%
chatbot(text)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (143 > 128). Running this sequence through the model will result in indexing errors
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-202ab1425408> in <cell line: 1>()
# ----> 1 chatbot(text)
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/conversational.py in __call__(self, conversations, num_workers, **kwargs)
#     285         elif isinstance(conversations, list) and isinstance(conversations[0], list):
#     286             conversations = [Conversation(conv) for conv in conversations]
# --> 287         outputs = super().__call__(conversations, num_workers=num_workers, **kwargs)
#     288         if isinstance(outputs, list) and len(outputs) == 1:
#     289             return outputs[0]
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1241             )
#    1242         else:
# -> 1243             return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#    1244
#    1245     def run_multi(self, inputs, preprocess_params, forward_params, postprocess_params):
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1248     def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1249         model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1250         model_outputs = self.forward(model_inputs, **forward_params)
#    1251         outputs = self.postprocess(model_outputs, **postprocess_params)
#    1252         return outputs
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in forward(self, model_inputs, **forward_params)
#    1148                 with inference_context():
#    1149                     model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1150                     model_outputs = self._forward(model_inputs, **forward_params)
#    1151                     model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1152             else:
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/conversational.py in _forward(self, model_inputs, **generate_kwargs)
#     304         if "max_length" not in generate_kwargs and "max_new_tokens" not in generate_kwargs:
#     305             generate_kwargs["max_new_tokens"] = 256
# --> 306         output_ids = self.model.generate(**model_inputs, **generate_kwargs)
#     307         if self.model.config.is_encoder_decoder:
#     308             start_position = 1
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1573         if self.config.is_encoder_decoder and "encoder_outputs" not in model_kwargs:
#    1574             # if model is encoder decoder encoder_outputs are created and added to `model_kwargs`
# -> 1575             model_kwargs = self._prepare_encoder_decoder_kwargs_for_generation(
#    1576                 inputs_tensor, model_kwargs, model_input_name, generation_config
#    1577             )
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in _prepare_encoder_decoder_kwargs_for_generation(self, inputs_tensor, model_kwargs, model_input_name, generation_config)
#     521         encoder_kwargs["return_dict"] = True
#     522         encoder_kwargs[model_input_name] = inputs_tensor
# --> 523         model_kwargs["encoder_outputs"]: ModelOutput = encoder(**encoder_kwargs)
#     524
#     525         return model_kwargs
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/blenderbot/modeling_blenderbot.py in forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     731             inputs_embeds = self.embed_tokens(input_ids)
#     732
# --> 733         embed_pos = self.embed_positions(input_shape)
#     734
#     735         hidden_states = inputs_embeds + embed_pos
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/blenderbot/modeling_blenderbot.py in forward(self, input_ids_shape, past_key_values_length)
#      85             past_key_values_length, past_key_values_length + seq_len, dtype=torch.long, device=self.weight.device
#      86         )
# ---> 87         return super().forward(positions)
#      88
#      89
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/sparse.py in forward(self, input)
#     161
#     162     def forward(self, input: Tensor) -> Tensor:
# --> 163         return F.embedding(
#     164             input, self.weight, self.padding_idx, self.max_norm,
#     165             self.norm_type, self.scale_grad_by_freq, self.sparse)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2262         # remove once script supports set_grad_enabled
#    2263         _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2264     return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#    2265
#    2266
#
# IndexError: index out of range in self
